# %%
import pickle
from matplotlib import pyplot as plt

# %% [markdown]
# # REINFORCE
# ### v_27_12_20__19_5031

# %%
data = pickle.load( open( "C:/Users/Tibovc/Desktop/MCT/Research Project/research_project/history_data/REINFORCE/game_history_data_v_27_12_20__19_5031.pkl", "rb" ) )

plt.plot(range(len(data)), data)
plt.xlabel("Episodes")
plt.ylabel("Total reward")
plt.title("Total reward/episode")
plt.show()

# %% [markdown]
# #### Conclusie
# - Deze agent kan kiezen uit 3 vormen.
# - In het begin doet hij willekeurige dingen maar na verloop van tijd plaatst hij elke vorm op dezelfde plek. Ook neemt hij altijd actie 1. Dit kan komen doordat hij een negatieve reward krijgt voor elke ongeldige zet. Hierdoor kan het zijn dat hij geen andere acties durft te nemen.

# %% [markdown]
# ### v_28_12_20__10_2058

# %%
data = pickle.load( open( "C:/Users/Tibovc/Desktop/MCT/Research Project/research_project/history_data/REINFORCE/game_history_data_v_28_12_20__10_2058.pkl", "rb" ) )

plt.plot(range(len(data)), data)
plt.xlabel("Episodes")
plt.ylabel("Total reward")
plt.title("Total reward/episode")
plt.show()

# %% [markdown]
# #### Conclusie
# -
